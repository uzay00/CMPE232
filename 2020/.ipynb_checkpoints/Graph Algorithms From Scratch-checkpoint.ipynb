# %%
import warnings
warnings.filterwarnings('ignore')

import networkx as nx
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Graph API

# %%
str_elist = """
4 2
3 2
6 0
0 1
2 0
11 12
12 9
9 10
9 11
8 9
10 12
11 4
4 3
3 5
7 8
8 7
5 4
0 5
6 4
6 9
7 6
2 3
"""

edge_list = [tuple(line.split(' ')) for line in str_elist.split('\n') if line != '']

# %%
class nodes():
    def __init__(self, name):
        self.name = name      # name type is string
        self.neighbors = []   # neighbors are nodes (not node names)
        self.visited = False
        self.prev = None
        
    def neighbors_name(self):
        """
        info about neighbors names
        """
        return [n.name for n in self.neighbors]
    
class digraph():
    def __init__(self, edge_list):
        self.edge_list = edge_list
        self.node_names = list(set([s for s,t in edge_list] + [t for s,t in edge_list]))
        self.nodes = {name:nodes(name) for name in self.node_names}
        
        self.create_graph()
        
    def create_graph(self):
        for s,t in self.edge_list:
            self.add_edge(s,t)
            
    def add_edge(self, source_name, target_name):
        """
        put target node in the neighbor list of source node
        """
        self.nodes[source_name].neighbors.append(self.nodes[target_name])
        
    def info(self):
        return {s:node_s.neighbors_name() for s,node_s in self.nodes.items()}
   
    def draw(self, color = 'lightblue'):
        """
            Usage of networkx for visualisation
        """
        G = nx.DiGraph()
        G.add_edges_from(self.edge_list)
        plt.figure(figsize=(20,8))
        nx.draw(G, node_size=2000, node_color=color, font_size= 30, with_labels=True)

# %%
g = digraph(edge_list)
g.draw()

# %%
g.info()
# Out:
# {'0': ['1', '5'],
#  '1': [],
#  '10': ['12'],
#  '11': ['12', '4'],
#  '12': ['9'],
#  '2': ['0', '3'],
#  '3': ['2', '5'],
#  '4': ['2', '3'],
#  '5': ['4'],
#  '6': ['0', '4', '9'],
#  '7': ['8', '6'],
#  '8': ['9', '7'],
#  '9': ['10', '11']}

# %% [markdown]
# # DFS

# %%
class depthFirstSearch():
    def __init__(self, G, s_name):
        self.G = G 
        self.traversal = []
        
        self.dfs(s_name)
        
    def dfs(self, s_name):
        self.G.nodes[s_name].visited = True
        self.traversal.append(s_name)
        
        for neig_name in self.G.nodes[s_name].neighbors_name():
            if not self.G.nodes[neig_name].visited:
                self.dfs(neig_name)
                self.G.nodes[neig_name].prev = s_name

# %%
elist = [('A', 'B'), ('B', 'D'), ('C', 'B'), ('C', 'D'), ('E', 'B'), ('E', 'D')]
g = digraph(elist)
g.draw()

# %%
search = depthFirstSearch(g, 'A')
visited = {v_name: v.visited for v_name,v  in g.nodes.items()}
visited
# Out:
# {'A': True, 'B': True, 'C': False, 'D': True, 'E': False}

# %%
search.traversal
# Out:
# ['A', 'B', 'D']

# %%
import numpy as np
import matplotlib.pyplot as plt

from matplotlib import animation, rc
from IPython.display import HTML
# %matplotlib inline

# %%
# First set up the figure, the axis, and the plot element we want to animate
fig, ax = plt.subplots()

ax.set_xlim(( 0, 2))
ax.set_ylim((-2, 2))

line, = ax.plot([], [], lw=2)

# %%
# initialization function: plot the background of each frame
def init():
    line.set_data([], [])
    return (line,)

# %%
# animation function. This is called sequentially
def animate(i):
    x = np.linspace(0, 2, 1000)
    y = np.sin(2 * np.pi * (x - 0.01 * i))
    line.set_data(x, y)
    return (line,)

# %%
# call the animator. blit=True means only re-draw the parts that have changed.
anim = animation.FuncAnimation(fig, animate, init_func=init,
                               frames=100, interval=20, blit=True)

# %%
HTML(anim.to_html5_video())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-5114ccf53b4c> in <module>()
# ----> 1 HTML(anim.to_html5_video())
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/matplotlib/animation.py in to_html5_video(self, embed_limit)
#    1407                 # We create a writer manually so that we can get the
#    1408                 # appropriate size for the tag
# -> 1409                 Writer = writers[rcParams['animation.writer']]
#    1410                 writer = Writer(codec='h264',
#    1411                                 bitrate=rcParams['animation.bitrate'],
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/matplotlib/animation.py in __getitem__(self, name)
#     168         if not self.avail:
#     169             raise RuntimeError("No MovieWriters available!")
# ...
